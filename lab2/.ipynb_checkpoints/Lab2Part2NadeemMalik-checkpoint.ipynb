# %% [markdown]
# ### **Assignment Part 2 - Nadeem Malik**

# %% [markdown]
# #### 1.) Load the provided three CSV files (players.csv, countries.csv, events.csv)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline

countries = pd.read_csv('countries.csv')
players = pd.read_csv('players.csv')
events = pd.read_csv('events.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### **2.) Count the total number of players whose names start with a vowel ('A', 'E', 'I', 'O', 'U'). (Hint: See Extracting Substrings)**

# %%
print players['name'].str.extract('^([AEOIU])').count()
# Out:
# 84

# %% [markdown]
# #### 3.) Find players from 'USA' whose names start with 'A'.

# %%
join = pd.merge(players, countries, on='country_id')
join.head(5)
players.groupby('country_id').head()

x = players[players['country_id'] =='USA'];

for n in x['name']:
    if n.startswith('A'):
        print n
# Out:
# Aaron Peirsol
# Adam Nelson
# Allyson Felix
# Alvin Harrison
# Amanda Beard
# Amanda Weir
# Amy van Dyken
# Angelo Taylor
# Anthony Ervin
# Antonio Pettigrew

# %% [markdown]
# #### 4.) Construct a dataframe with two columns: country_name, num_players. Use groupby.

# %%
p = players.groupby('country_id')
x = p.size()
y = p.groups
countries_size = {}
d = {}

for i in y:
    d[i] = len(y[i])

cols = ['country_name', 'num_players']

df = pd.DataFrame(list(d.iteritems()), columns=cols)
print df
# Out:
#    country_name  num_players
# 0           BAR            1
# 1           DEN            2
# 2           USA           88
# 3           DOM            1
# 4           NED           13
# 5           SWE            9
# 6           UKR            9
# 7           CRC            1
# 8           GBR           12
# 9           CAN            1
# 10          NGR           12
# 11          ISL            1
# 12          ETH           12
# 13          CMR            1
# 14          BAH            5
# 15          GRE            7
# 16          GER           22
# 17          ROM           10
# 18          HUN            4
# 19          POR            3
# 20          CRO            1
# 21          POL            5
# 22          BUL            1
# 23          ERI            1
# 24          TRI            2
# 25          FRA           10
# 26          EST            2
# 27          SVK            1
# 28          LTU            2
# 29          ESP            4
# 30          SRI            1
# 31          CHN            8
# 32          BLR            7
# 33          AUS           34
# 34          SLO            1
# 35          IRL            1
# 36          CUB           12
# 37          RUS           38
# 38          ZIM            1
# 39          FIN            1
# 40          MOZ            1
# 41          MAR            5
# 42          JPN           16
# 43          CZR            3
# 44          ALG            4
# 45          TUR            1
# 46          RSA           10
# 47          ITA           12
# 48          AUT            2
# 49          KSA            1
# 50          JAM           18
# 51          NOR            3
# 52          ARG            1
# 53          LAT            2
# 54          KAZ            2
# 55          MEX            3
# 56          BRA            9
# 57          KEN           13

# %% [markdown]
# #### 5.) Convert the above left outer join query (last question in the SQL assignment) into pandas equivalent. See http://pandas.pydata.org/pandas-docs/stable/merging.html for details on how to do outer joins in pandas.

# %%
a = pd.merge(countries, players, how='left', on='country_id')
a.groupby('country_id')
a = a.rename(columns={'name_x': 'name'})

a.groupby('name').apply(lambda x: pd.Series(dict(
    count=(x.birthdate.str.startswith('1975')).sum(),
)))
# Out:
#                                           count
# name
# Algeria                                       0
# Argentina                                     0
# Australia                                     3
# Austria                                       0
# Barbados                                      0
# Belarus                                       1
# Brazil                                        1
# Bulgaria                                      0
# Cameroon                                      0
# Canada                                        0
# China                                         0
# Costa Rica                                    0
# Croatia                                       0
# Cuba                                          1
# Czech Republic                                1
# Denmark                                       1
# Dominican Republic                            0
# Eritrea                                       1
# Estonia                                       1
# Ethiopia                                      1
# Finland                                       0
# France                                        0
# Germany                                       1
# Greece                                        0
# Hungary                                       0
# Iceland                                       0
# Ireland                                       0
# Italy                                         1
# Jamaica                                       1
# Japan                                         3
# Kazakhstan                                    1
# Kenya                                         0
# Latvia                                        0
# Lithuania                                     1
# Mexico                                        0
# Morocco                                       0
# Mozambique                                    0
# Netherlands                                   0
# Nigeria                                       0
# Norway                                        0
# Poland                                        0
# Portugal                                      0
# Romania                                       1
# Russia                                        0
# Saudi Arabia                                  0
# Slovakia                                      0
# Slovenia                                      0
# South Africa                                  4
# Spain                                         0
# Sri Lanka                                     0
# Sweden                                        2
# The Bahamas                                   0
# Trinidad and Tobago                           0
# Turkey                                        0
# Ukraine                                       0
# United Kingdom                                1
# United States                                 5
# Zimbabwe                                      0
